# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.style.use('ggplot')

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-6d4e7b36-81a9-42dc-adf7-735d6866d94f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d4e7b36-81a9-42dc-adf7-735d6866d94f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Cleaned Dataset - Bangladesh.csv to Cleaned Dataset - Bangladesh.csv
# Saving Cleaned Dataset - Binodon.csv to Cleaned Dataset - Binodon.csv
# Saving Cleaned Dataset - Sports.csv to Cleaned Dataset - Sports.csv
# Saving Cleaned Dataset - World.csv to Cleaned Dataset - World.csv

# %% [markdown]
# # Binodon Dataset

# %%
dataset = pd.read_csv('/content/Cleaned Dataset - Binodon.csv')[["Sentence 1", "Sentence 2", "Rounding"]]

# %%
number_of_ones=0
number_of_zeros=0
number_of_blanks=0
for number in dataset['Rounding']:
  if number==1:
    number_of_ones+=1
  elif number==0:
    number_of_zeros+=1
  else:
    number_of_blanks+=1
print(f"There are {number_of_ones}  one pairs")
print(f"There are {number_of_zeros}  zero pairs")
print(f"There are {number_of_blanks}  undecided pairs")
# Out:
# There are 619  one pairs
# There are 955  zero pairs
# There are 369  undecided pairs

# %%
dataset = dataset.dropna()
datasettotal=dataset
dataset.head()
# Out:
#                            Sentence 1  ... Rounding
# 0  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...      1.0
# 1  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...      0.0
# 3  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...      0.0
# 4  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...      0.0
# 5                  আসছে দুই প্রীতিলতা  ...      0.0
#
# [5 rows x 3 columns]

# %%
dataset["Rounding"].value_counts().plot.pie(labels=['Not Paraphrase', 'Paraphrase'], autopct='%.2f', figsize=(6, 6),legend=True)

# %%
wc1 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 1']]
wc2 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 2']]

cc1 = [len(sent) for sent in dataset['Sentence 1']]
cc2 = [len(sent) for sent in dataset['Sentence 2']]

dataset['WordCount1'] = wc1
dataset['WordCount2'] = wc2
dataset['CharCount1'] = cc1
dataset['CharCount2'] = cc2
dataset.head()
# Out:
#                            Sentence 1  ... CharCount2
# 0  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...         18
# 1  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...         34
# 3  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...         25
# 4  অবশেষে প্রীতিলতার শুটিং শুরু হচ্ছে  ...         42
# 5                  আসছে দুই প্রীতিলতা  ...         34
#
# [5 rows x 7 columns]

# %%
dataset.describe()
# Out:
#           Rounding   WordCount1   WordCount2   CharCount1   CharCount2
# count  1574.000000  1574.000000  1574.000000  1574.000000  1574.000000
# mean      0.393266     7.167090     7.303050    46.688056    47.645489
# std       0.488630     2.642632     2.657193    16.828967    16.981688
# min       0.000000     2.000000     2.000000     9.000000     9.000000
# 25%       0.000000     5.000000     5.000000    34.000000    35.000000
# 50%       0.000000     7.000000     7.000000    44.000000    46.000000
# 75%       1.000000     9.000000     9.000000    56.000000    58.000000
# max       1.000000    16.000000    16.000000   109.000000   106.000000

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Frequency')

ax1.set_title("Word Count")
ax1.set_xlabel('Word Count')
ax1.set_ylabel('Frequency')
dataset["WordCount1"].sort_values(ignore_index=True).plot.hist(ax=ax1)
ax2.set_title("Character Count")
ax2.set_xlabel('Character Count')
ax2.set_ylabel('Frequency')
dataset["CharCount1"].sort_values(ignore_index=True).plot.hist(ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Count vs Paraphrase')

ax1.set_title("Word Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='WordCount1', y='WordCount2', color='DarkBlue', s=40, label="Not Paraphrase", ax = ax1)
dataset[dataset["Rounding"] == 1].plot.scatter(x='WordCount1', y='WordCount2', color='r', marker='+', s=40, label="Paraphrase", ax = ax1)

ax2.set_title("Character Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='CharCount1', y='CharCount2', color='DarkBlue', s=20, label="Not Paraphrase", ax = ax2)
dataset[dataset["Rounding"] == 1].plot.scatter(x='CharCount1', y='CharCount2', color='r', marker='+', s=20, label="Paraphrase", ax = ax2)

# %% [markdown]
# # Sports Dataset

# %%
dataset = pd.read_csv('/content/Cleaned Dataset - Sports.csv')[["Sentence 1", "Sentence 2", "Rounding"]]

# %%
number_of_ones=0
number_of_zeros=0
number_of_blanks=0
for number in dataset['Rounding']:
  if number==1:
    number_of_ones+=1
  elif number==0:
    number_of_zeros+=1
  else:
    number_of_blanks+=1
print(f"There are {number_of_ones}  one pairs")
print(f"There are {number_of_zeros}  zero pairs")
print(f"There are {number_of_blanks}  undecided pairs")
# Out:
# There are 638  one pairs
# There are 1143  zero pairs
# There are 403  undecided pairs

# %%
dataset = dataset.dropna()
datasettotal+=dataset
dataset.head()
# Out:
#                                           Sentence 1  ... Rounding
# 0  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...      1.0
# 1  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...      1.0
# 2  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...      0.0
# 3  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...      1.0
# 4  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...      0.0
#
# [5 rows x 3 columns]

# %%
dataset["Rounding"].value_counts().plot.pie(labels=['Not Paraphrase', 'Paraphrase'], autopct='%.2f', figsize=(6, 6),legend=True)

# %%
wc1 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 1']]
wc2 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 2']]

cc1 = [len(sent) for sent in dataset['Sentence 1']]
cc2 = [len(sent) for sent in dataset['Sentence 2']]

dataset['WordCount1'] = wc1
dataset['WordCount2'] = wc2
dataset['CharCount1'] = cc1
dataset['CharCount2'] = cc2
dataset.head()
# Out:
#                                           Sentence 1  ... CharCount2
# 0  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...         57
# 1  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...         44
# 2  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...         63
# 3  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...         44
# 4  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...         63
#
# [5 rows x 7 columns]

# %%
dataset.describe()
# Out:
#           Rounding   WordCount1   WordCount2   CharCount1   CharCount2
# count  1781.000000  1781.000000  1781.000000  1781.000000  1781.000000
# mean      0.358226     6.785514     6.919708    45.954520    46.924761
# std       0.479614     2.279373     2.370407    14.688169    15.168787
# min       0.000000     2.000000     2.000000    14.000000    15.000000
# 25%       0.000000     5.000000     5.000000    36.000000    36.000000
# 50%       0.000000     6.000000     7.000000    44.000000    45.000000
# 75%       1.000000     8.000000     8.000000    54.000000    56.000000
# max       1.000000    16.000000    16.000000   102.000000   102.000000

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Frequency')

ax1.set_title("Word Count")
ax1.set_xlabel('Word Count')
ax1.set_ylabel('Frequency')
dataset["WordCount1"].sort_values(ignore_index=True).plot.hist(ax=ax1)
ax2.set_title("Character Count")
ax2.set_xlabel('Character Count')
ax2.set_ylabel('Frequency')
dataset["CharCount1"].sort_values(ignore_index=True).plot.hist(ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Count vs Paraphrase')

ax1.set_title("Word Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='WordCount1', y='WordCount2', color='DarkBlue', s=40, label="Not Paraphrase", ax = ax1)
dataset[dataset["Rounding"] == 1].plot.scatter(x='WordCount1', y='WordCount2', color='r', marker='+', s=40, label="Paraphrase", ax = ax1)

ax2.set_title("Character Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='CharCount1', y='CharCount2', color='DarkBlue', s=20, label="Not Paraphrase", ax = ax2)
dataset[dataset["Rounding"] == 1].plot.scatter(x='CharCount1', y='CharCount2', color='r', marker='+', s=20, label="Paraphrase", ax = ax2)

# %% [markdown]
# # Bangladesh Dataset

# %%
dataset = pd.read_csv('/content/Cleaned Dataset - Bangladesh.csv')[["Sentence 1", "Sentence 2", "Rounding"]]

# %%
number_of_ones=0
number_of_zeros=0
number_of_blanks=0
for number in dataset['Rounding']:
  if number==1:
    number_of_ones+=1
  elif number==0:
    number_of_zeros+=1
  else:
    number_of_blanks+=1
print(f"There are {number_of_ones}  one pairs")
print(f"There are {number_of_zeros}  zero pairs")
print(f"There are {number_of_blanks}  undecided pairs")
# Out:
# There are 742  one pairs
# There are 1056  zero pairs
# There are 385  undecided pairs

# %%
dataset = dataset.dropna()
datasettotal+=dataset
dataset.head()
# Out:
#                          Sentence 1  ... Rounding
# 0  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...      0.0
# 1  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...      0.0
# 2  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...      0.0
# 3  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...      0.0
# 4  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...      0.0
#
# [5 rows x 3 columns]

# %%
dataset["Rounding"].value_counts().plot.pie(labels=['Not Paraphrase', 'Paraphrase'], autopct='%.2f', figsize=(6, 6),legend=True)

# %%
wc1 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 1']]
wc2 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 2']]

cc1 = [len(sent) for sent in dataset['Sentence 1']]
cc2 = [len(sent) for sent in dataset['Sentence 2']]

dataset['WordCount1'] = wc1
dataset['WordCount2'] = wc2
dataset['CharCount1'] = cc1
dataset['CharCount2'] = cc2
dataset.head()
# Out:
#                          Sentence 1  ... CharCount2
# 0  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...         39
# 1  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...         48
# 2  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...         38
# 3  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...         42
# 4  রায়ের পর হাসছিলেন রিফাত ফরাজীরা  ...         37
#
# [5 rows x 7 columns]

# %%
dataset.describe()
# Out:
#           Rounding   WordCount1   WordCount2   CharCount1   CharCount2
# count  1798.000000  1798.000000  1798.000000  1798.000000  1798.000000
# mean      0.412681     7.017241     7.081758    46.628476    46.804783
# std       0.492453     1.965544     1.939396    13.056954    13.168538
# min       0.000000     2.000000     2.000000    12.000000     8.000000
# 25%       0.000000     6.000000     6.000000    37.000000    37.000000
# 50%       0.000000     7.000000     7.000000    46.000000    46.000000
# 75%       1.000000     8.000000     8.000000    55.000000    55.000000
# max       1.000000    17.000000    17.000000   112.000000    91.000000

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Frequency')

ax1.set_title("Word Count")
ax1.set_xlabel('Word Count')
ax1.set_ylabel('Frequency')
dataset["WordCount1"].sort_values(ignore_index=True).plot.hist(ax=ax1)
ax2.set_title("Character Count")
ax2.set_xlabel('Character Count')
ax2.set_ylabel('Frequency')
dataset["CharCount1"].sort_values(ignore_index=True).plot.hist(ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Count vs Paraphrase')

ax1.set_title("Word Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='WordCount1', y='WordCount2', color='DarkBlue', s=40, label="Not Paraphrase", ax = ax1)
dataset[dataset["Rounding"] == 1].plot.scatter(x='WordCount1', y='WordCount2', color='r', marker='+', s=40, label="Paraphrase", ax = ax1)

ax2.set_title("Character Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='CharCount1', y='CharCount2', color='DarkBlue', s=20, label="Not Paraphrase", ax = ax2)
dataset[dataset["Rounding"] == 1].plot.scatter(x='CharCount1', y='CharCount2', color='r', marker='+', s=20, label="Paraphrase", ax = ax2)

# %% [markdown]
# # World

# %%
dataset = pd.read_csv('/content/Cleaned Dataset - World.csv')[["Sentence 1", "Sentence 2", "Rounding"]]

# %%
number_of_ones=0
number_of_zeros=0
number_of_blanks=0
for number in dataset['Rounding']:
  if number==1:
    number_of_ones+=1
  elif number==0:
    number_of_zeros+=1
  else:
    number_of_blanks+=1
print(f"There are {number_of_ones}  one pairs")
print(f"There are {number_of_zeros}  zero pairs")
print(f"There are {number_of_blanks}  undecided pairs")
# Out:
# There are 856  one pairs
# There are 1384  zero pairs
# There are 440  undecided pairs

# %%
dataset = dataset.dropna()
datasettotal+=dataset
dataset.head()
# Out:
#                                           Sentence 1  ... Rounding
# 0          উইঘুরদের পর চীনের টার্গেট উৎসুল মুসলমানরা  ...      1.0
# 1          উইঘুরদের পর চীনের টার্গেট উৎসুল মুসলমানরা  ...      1.0
# 2      এবার উৎসুল মুসলমানদের ওপর চীনের 'দমন-নিপীড়ন'  ...      1.0
# 3  নার্সারির শিশুদের বিষপ্রয়োগ, চীনে শিক্ষিকার মৃ...  ...      1.0
# 4  রাজ কাপুর, দিলীপ কুমারের পূর্বপুরুষের বাড়ি কি...  ...      1.0
#
# [5 rows x 3 columns]

# %%
dataset["Rounding"].value_counts().plot.pie(labels=['Not Paraphrase', 'Paraphrase'], autopct='%.2f', figsize=(6, 6),legend=True)

# %%
wc1 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 1']]
wc2 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 2']]

cc1 = [len(sent) for sent in dataset['Sentence 1']]
cc2 = [len(sent) for sent in dataset['Sentence 2']]

dataset['WordCount1'] = wc1
dataset['WordCount2'] = wc2
dataset['CharCount1'] = cc1
dataset['CharCount2'] = cc2
dataset.head()
# Out:
#                                           Sentence 1  ... CharCount2
# 0          উইঘুরদের পর চীনের টার্গেট উৎসুল মুসলমানরা  ...         45
# 1          উইঘুরদের পর চীনের টার্গেট উৎসুল মুসলমানরা  ...         31
# 2      এবার উৎসুল মুসলমানদের ওপর চীনের 'দমন-নিপীড়ন'  ...         31
# 3  নার্সারির শিশুদের বিষপ্রয়োগ, চীনে শিক্ষিকার মৃ...  ...         52
# 4  রাজ কাপুর, দিলীপ কুমারের পূর্বপুরুষের বাড়ি কি...  ...         62
#
# [5 rows x 7 columns]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Frequency')

ax1.set_title("Word Count")
ax1.set_xlabel('Word Count')
ax1.set_ylabel('Frequency')
dataset["WordCount1"].sort_values(ignore_index=True).plot.hist(ax=ax1)
ax2.set_title("Character Count")
ax2.set_xlabel('Character Count')
ax2.set_ylabel('Frequency')
dataset["CharCount1"].sort_values(ignore_index=True).plot.hist(ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Count vs Paraphrase')

ax1.set_title("Word Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='WordCount1', y='WordCount2', color='DarkBlue', s=40, label="Not Paraphrase", ax = ax1)
dataset[dataset["Rounding"] == 1].plot.scatter(x='WordCount1', y='WordCount2', color='r', marker='+', s=40, label="Paraphrase", ax = ax1)

ax2.set_title("Character Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='CharCount1', y='CharCount2', color='DarkBlue', s=20, label="Not Paraphrase", ax = ax2)
dataset[dataset["Rounding"] == 1].plot.scatter(x='CharCount1', y='CharCount2', color='r', marker='+', s=20, label="Paraphrase", ax = ax2)

# %% [markdown]
# # Total Dataset

# %%
from glob import glob

# %%
stock_files=glob('/content/Cleaned Dataset - *.csv')
stock_files
# Out:
# ['/content/Cleaned Dataset - Sports.csv',
#  '/content/Cleaned Dataset - World.csv',
#  '/content/Cleaned Dataset - Binodon.csv',
#  '/content/Cleaned Dataset - Bangladesh.csv']

# %%
dataset=pd.concat((pd.read_csv(file).assign(filename = file)
          for file in stock_files), ignore_index=True)
dataset
# Out:
#                                              Sentence 1  ...                                   filename
# 0     ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...      /content/Cleaned Dataset - Sports.csv
# 1     ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...      /content/Cleaned Dataset - Sports.csv
# 2     ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...      /content/Cleaned Dataset - Sports.csv
# 3     আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...      /content/Cleaned Dataset - Sports.csv
# 4     আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...      /content/Cleaned Dataset - Sports.csv
# ...                                                 ...  ...                                        ...
# 8985  ফতুল্লায় সিগারেটের আগুনে স্বামীর মৃত্যু, স্ত্...  ...  /content/Cleaned Dataset - Bangladesh.csv
# 8986  ফতুল্লায় সিগারেটের আগুনে স্বামীর মৃত্যু, স্ত্...  ...  /content/Cleaned Dataset - Bangladesh.csv
# 8987  সিগারেট থেকে ঘরে আগুন: বাবার মৃত্যু, মা ও মেয়ে...  ...  /content/Cleaned Dataset - Bangladesh.csv
# 8988  সিগারেট থেকে ঘরে আগুন: বাবার মৃত্যু, মা ও মেয়ে...  ...  /content/Cleaned Dataset - Bangladesh.csv
# 8989  ফতুল্লায় অগ্নিকাণ্ডে স্বামীর মৃত্যু, স্ত্রী-ক...  ...  /content/Cleaned Dataset - Bangladesh.csv
#
# [8990 rows x 11 columns]

# %%
number_of_ones=0
number_of_zeros=0
number_of_blanks=0
for number in dataset['Rounding']:
  if number==1:
    number_of_ones+=1
  elif number==0:
    number_of_zeros+=1
  else:
    number_of_blanks+=1
print(f"There are {number_of_ones}  one pairs")
print(f"There are {number_of_zeros}  zero pairs")
print(f"There are {number_of_blanks}  undecided pairs")
# Out:
# There are 2855  one pairs
# There are 4538  zero pairs
# There are 1597  undecided pairs

# %%
dataset = dataset.dropna()
dataset.head()
# Out:
#                                           Sentence 1  ...                               filename
# 0  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...  /content/Cleaned Dataset - Sports.csv
# 1  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...  /content/Cleaned Dataset - Sports.csv
# 2  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...  /content/Cleaned Dataset - Sports.csv
# 3  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...  /content/Cleaned Dataset - Sports.csv
# 4  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...  /content/Cleaned Dataset - Sports.csv
#
# [5 rows x 11 columns]

# %%
dataset["Rounding"].value_counts().plot.pie(labels=['Not Paraphrase', 'Paraphrase'], autopct='%.2f', figsize=(6, 6),legend=True)

# %%
wc1 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 1']]
wc2 = [len(re.sub('_|-|!|:| |,', ' ', sent).split()) for sent in dataset['Sentence 2']]

cc1 = [len(sent) for sent in dataset['Sentence 1']]
cc2 = [len(sent) for sent in dataset['Sentence 2']]

dataset['WordCount1'] = wc1
dataset['WordCount2'] = wc2
dataset['CharCount1'] = cc1
dataset['CharCount2'] = cc2
dataset.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#                                           Sentence 1  ... CharCount2
# 0  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...         57
# 1  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...         44
# 2  ইংল্যান্ডের বিপক্ষে দেশের মাটিতেই খেলার ভাবনা ...  ...         63
# 3  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...         44
# 4  আইপিএল বিদেশে হলেও ইংল্যান্ডের সঙ্গে দেশেই খেল...  ...         63
#
# [5 rows x 15 columns]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Frequency')

ax1.set_title("Word Count")
ax1.set_xlabel('Word Count')
ax1.set_ylabel('Frequency')
dataset["WordCount1"].sort_values(ignore_index=True).plot.hist(ax=ax1)
ax2.set_title("Character Count")
ax2.set_xlabel('Character Count')
ax2.set_ylabel('Frequency')
dataset["CharCount1"].sort_values(ignore_index=True).plot.hist(ax=ax2)

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.suptitle('Word and Character Count vs Paraphrase')

ax1.set_title("Word Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='WordCount1', y='WordCount2', color='DarkBlue', s=40, label="Not Paraphrase", ax = ax1)
dataset[dataset["Rounding"] == 1].plot.scatter(x='WordCount1', y='WordCount2', color='r', marker='+', s=40, label="Paraphrase", ax = ax1)

ax2.set_title("Character Count vs Paraphrase")
dataset[dataset["Rounding"] == 0].plot.scatter(x='CharCount1', y='CharCount2', color='DarkBlue', s=20, label="Not Paraphrase", ax = ax2)
dataset[dataset["Rounding"] == 1].plot.scatter(x='CharCount1', y='CharCount2', color='r', marker='+', s=20, label="Paraphrase", ax = ax2)
